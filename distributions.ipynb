# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import random
import pandas as pd
import math

# %%
stats.binom.stats(8, 0.4)
# Out:
# (array(3.2), array(1.92))

# %%
draws = 100
for j in np.arange(0.1, 0.6, 0.1):
    m = []
    for i in range(draws):
        m.append(stats.binom.pmf(i, draws,  j))
    plt.plot(m, label='P_success =' +str(j))
    plt.xlabel('Number of Successes')
    plt.ylabel('Probability')
    plt.legend()

# %%
mu = 0
for i in range(1, 4, 1):
    variance = i
    sigma = math.sqrt(variance)
    x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
    plt.plot(x, stats.norm.pdf(x, mu, sigma), label='sigma = '+str(i))
plt.xlabel('Value')
plt.ylabel('Probability')
plt.legend()
plt.show()

# %%
def poisson(lam, k):
    x = lam**k * (np.exp(-lam))/math.factorial(k)
    return x

lam = 3
vals = []
x = range(0,30,1)
print(x)
for i in x:
    vals.append(poisson(lam, i))

plt.plot(x, np.cumsum(vals))
plt.xlabel('Value')
plt.ylabel('Probability')
plt.title('Probability of <x> events in 1 year')
plt.show()
# Out:
# range(0, 30)
